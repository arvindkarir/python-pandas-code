# %%
import pandas as pd
import numpy as np
import pickle
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_pickle('./nov_conn.pickle')
# print(df .head(5))

# %%
df.columns
# Out:
# Index(['visit_time_utc', 'login_type', 'age_range', 'gender', 'postal_code',
#        'total_dwell_min', 'top_space_1_name', 'top_space_1_dwell_min',
#        'top_space_2_name', 'top_space_2_dwell_min',
#        ...
#        'top_space_56_name', 'top_space_56_dwell_min', 'top_space_57_name',
#        'top_space_57_dwell_min', 'top_space_58_name', 'top_space_58_dwell_min',
#        'top_space_59_name', 'top_space_59_dwell_min', 'top_space_60_name',
#        'top_space_60_dwell_min'],
#       dtype='object', length=126)

# %%
df.gender.unique()
# Out:
# array(['male', 'female', nan, 'other', 'female (hidden)', 'male (hidden)'], dtype=object)

# %%
df.age_range.unique()
# Out:
# array(['15~30', nan, '30~45', '60~75', '45~60', '75+', '0~15'], dtype=object)

# %%
df.dropna(subset=['gender', 'age_range'], inplace=True)

# %%
df.head()
# Out:
#   visit_time_utc login_type age_range  gender postal_code  total_dwell_min  \
# 0     2017-11-01          f     15~30    male     M3H 5K3               44
# 1     2017-11-01          f     15~30  female     M6M 2A1                8
# 2     2017-11-01          f     15~30    male     L1W 1B9               25
# 5     2017-11-01          f     15~30    male      L4H3A8              293
# 6     2017-11-01          f     15~30  female      M8W1X6                7
#
#          top_space_1_name  top_space_1_dwell_min top_space_2_name  \
# 0                La Senza                     44              NaN
# 1            Hudson's Bay                      8       Forever 21
# 2  The Cheesecake Factory                     17     Jack & Jones
# 5                 Pandora                    179           Davids
# 6                 Mappins                      5    Sporting Life
#
#    top_space_2_dwell_min           ...           top_space_56_name  \
# 0                    NaN           ...                         NaN
# 1                    0.0           ...                         NaN
# 2                    6.0           ...                         NaN
# 5                   53.0           ...                         NaN
# 6                    1.0           ...                         NaN
#
#    top_space_56_dwell_min top_space_57_name  top_space_57_dwell_min  \
# 0                     NaN               NaN                     NaN
# 1                     NaN               NaN                     NaN
# 2                     NaN               NaN                     NaN
# 5                     NaN               NaN                     NaN
# 6                     NaN               NaN                     NaN
#
#   top_space_58_name  top_space_58_dwell_min top_space_59_name  \
# 0               NaN                     NaN               NaN
# 1               NaN                     NaN               NaN
# 2               NaN                     NaN               NaN
# 5               NaN                     NaN               NaN
# 6               NaN                     NaN               NaN
#
#    top_space_59_dwell_min top_space_60_name  top_space_60_dwell_min
# 0                     NaN               NaN                     NaN
# 1                     NaN               NaN                     NaN
# 2                     NaN               NaN                     NaN
# 5                     NaN               NaN                     NaN
# 6                     NaN               NaN                     NaN
#
# [5 rows x 126 columns]

# %%
df.gender.unique()
# Out:
# array(['male', 'female', 'other', 'female (hidden)', 'male (hidden)'], dtype=object)

# %%
d = {'male':0, 'female':1, 'female (hidden)':1, 'male (hidden)':0, 'other':2}
df['gender'] = df['gender'].map(d)

# %%
df = df[df['gender'] != 2]

# %%
df.gender.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.age_range.unique()
# Out:
# array(['15~30', '30~45', '60~75', '45~60', '75+', '0~15'], dtype=object)

# %%
# d = {'0~15':'youth','15~30':'young', '30~45':'middle', '45~60':'mature', '60~75':'older', '75+':'old' }
d = {'0~15':1,'15~30':2, '30~45':3, '45~60':4, '60~75':5, '75+':6}
df['age'] = df.loc[:, 'age_range'].map(d)

# %%
df.age.unique()
# Out:
# array([2, 3, 5, 4, 6, 1], dtype=int64)

# %%
# %matplotlib inline
sns_plot = sns.pairplot(df, x_vars=['gender','age'], y_vars='total_dwell_min', size=20, aspect=0.3, kind='reg')
sns_plot.savefig('Regression_gender_age_dwell_time.png')

# %%
dfemale = df.loc[df['gender']==1]

# %%
dfemale.head()
# Out:
#    visit_time_utc login_type age_range  gender postal_code  total_dwell_min  \
# 1      2017-11-01          f     15~30       1     M6M 2A1                8
# 6      2017-11-01          f     15~30       1      M8W1X6                7
# 10     2017-11-01          f     15~30       1      M9W4E9              310
# 11     2017-11-01          f     30~45       1      M9N3R7              188
# 15     2017-11-01          f     15~30       1     M2K 1A3              323
#
#         top_space_1_name  top_space_1_dwell_min              top_space_2_name  \
# 1           Hudson's Bay                      8                    Forever 21
# 6                Mappins                      5                 Sporting Life
# 10  Restoration Hardware                    178                         Levis
# 11          Michael Kors                    152                    Kate Spade
# 15             Arc teryx                    310  Walk & Wear Fine Shoe Repair
#
#     top_space_2_dwell_min ...  top_space_56_dwell_min  top_space_57_name  \
# 1                     0.0 ...                     NaN                NaN
# 6                     1.0 ...                     NaN                NaN
# 10                  113.0 ...                     NaN                NaN
# 11                   10.0 ...                     NaN                NaN
# 15                   12.0 ...                     NaN                NaN
#
#    top_space_57_dwell_min  top_space_58_name top_space_58_dwell_min  \
# 1                     NaN                NaN                    NaN
# 6                     NaN                NaN                    NaN
# 10                    NaN                NaN                    NaN
# 11                    NaN                NaN                    NaN
# 15                    NaN                NaN                    NaN
#
#     top_space_59_name top_space_59_dwell_min  top_space_60_name  \
# 1                 NaN                    NaN                NaN
# 6                 NaN                    NaN                NaN
# 10                NaN                    NaN                NaN
# 11                NaN                    NaN                NaN
# 15                NaN                    NaN                NaN
#
#    top_space_60_dwell_min  age
# 1                     NaN    2
# 6                     NaN    2
# 10                    NaN    2
# 11                    NaN    3
# 15                    NaN    2
#
# [5 rows x 127 columns]

# %%
# plot without regression line
# sns.regplot(x=dfemale['age'], y=dfemale['total_dwell_min'], fit_reg=False)

# %%
# various other options for scatter plots
from matplotlib import rcParams
rcParams['figure.figsize'] = 11.7,8.27
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.jointplot(x=dfemale['age'], y=dfemale['total_dwell_min'], kind='kde', color='skyblue') # a 2-d contour plot
# sns.jointplot(x=dfemale['age'], y=dfemale['total_dwell_min'], kind='hex') # a hexbin plot
# sns.jointplot(x=dfemale['age'], y=dfemale['total_dwell_min'], kind='scatter') # a basic scatter plot
# sns.jointplot(x=dfemale['age'], y=dfemale['total_dwell_min'], kind='scatter', s=200, color='m', edgecolor="skyblue", linewidth=1) # with customization
# sns_plot.savefig('Regression_females_age_dwell_time.png')

# %%
stores = df1['store_name'].unique().tolist()
for store in stores:
    print(store, '=' , df1['traffic_2'][df1['store_name'] == store].sum() )
# Out:
# Nadege Mens = 19886
# Babaton Ladies = 146041
# Ent H = 62300
# Subway = 937491
# Shoppers Mens = 92839
# Shoppers Ladies = 135372
# Tim Hortons = 1083874
# Source = 1145263
# Ent A1 PB = 344735
# Ent A3 Sport Chek = 735572
# Ent J3 Shoppers = 352678
# Ent A2 Jamies = 275992
# Holt Flow = 1092490
# Go Transit = 131306
# Scotia Flow = 1064227
# Ent E = 79669
# Ent G Microsoft = 328101
# Harry Rosen Flow = 455034
# E Parkade P1-N = 75623
# Ent J1 = 84631
# Starbucks Mens = 121926
# Holt Renfrew Ext = 47662
# E Parkade P2-S = 56663
# E Parkade P4-S = 39889
# E Parkade P5-S = 20704
# Rest H CO = 178395
# Pandora Mens = 144581
# FC Ladies = 120919
# E Parkade P1-S = 89987
# F Parkade P1 = 255111
# FC Elev N = 126461
# E Parkade P3-N = 61516
# FC Mens = 106876
# Ent J2 = 49303
# FC Elev S = 82778
# E Parkade P4-N = 33815
# E Parkade P5-N = 23026
# Pandora Ladies = 198419
# FC Esc N = 776381
# Babaton Mens = 113983
# Bvlgari Ladies = 127771
# Bvlgari Mens = 109459
# Starbucks Ladies = 140471
# FC Emp Mens = 4322
# Nadege Family = 7945
# Starbucks Fam2 = 8299
# Starbucks Fam1 = 10174
# Nadege Ladies = 24128
# Bay West J3 = 130344
# Pandora Nursing = 11690
# E Parkade P2-N = 84886
# FC Emp Ladies = 5715
# F Parkade P2 = 125604
# E Parkade P3-S = 52004
# Pandora Family = 10318
# Nordstrom CO = 605238
# Ent F Valet = 72370
# E Parkade P1-E = 47348
# F Parkade Holt P2 = 13360
# Bay North A1 = 175797
# F Parkade Holt P1 = 17743
# Nord P1 East = 31467
# C Park Nord L2 = 5506
# E Parkade P5-E = 6429
# E Parkade P4-E = 12524
# C Park Nord L1 = 24006
# E Parkade P3-E = 36971
# E Parkade P2-E = 34647
# Cheescake CO = 238963
# Rest H Ext = 8723

# %%
df1.dtypes
# Out:
# time_start    object
# time_end      object
# traffic_1      int64
# traffic_2      int64
# store_name    object
# dtype: object

# %%
df1['day'] = pd.DatetimeIndex(df1['time_start']).day
df1['month'] = pd.DatetimeIndex(df1['time_start']).month
df1['year'] = pd.DatetimeIndex(df1['time_start']).year

# %%
import dateutil
df1['date'] = df1['time_start'].apply(dateutil.parser.parse, yearfirst=True)

# %%
df1['week'] = df1['date'].dt.week
df1.head(50)
# Out:
#              time_start             time_end  traffic_1  traffic_2  \
# 0   2017-12-01 00:00:00  2017-12-01 00:15:00          1          1
# 1   2017-12-01 00:00:00  2017-12-01 00:15:00          1          1
# 2   2017-12-01 00:00:00  2017-12-01 00:15:00          1          1
# 3   2017-12-01 00:00:00  2017-12-01 00:15:00          1         12
# 4   2017-12-01 00:00:00  2017-12-01 00:15:00          2          1
# 5   2017-12-01 00:00:00  2017-12-01 00:15:00          0          1
#
# 45    Ent G Microsoft    1     12  2017 2017-12-01 00:15:00    48
# 46   Harry Rosen Flow    1     12  2017 2017-12-01 00:15:00    48
# 47     E Parkade P1-S    1     12  2017 2017-12-01 00:15:00    48
# 48       F Parkade P1    1     12  2017 2017-12-01 00:15:00    48
# 49     E Parkade P1-N    1     12  2017 2017-12-01 00:15:00    48

# %%
mens = ['Shoppers Mens','Nadege Mens','Harry Rosen Flow','Starbucks Mens','Pandora Mens','Bvlgari Mens','Babaton Mens','FC Mens','FC Emp Mens']
womens = ['Shoppers Ladies','Babaton Ladies','Holt Renfrew Ext','Holt Flow','FC Ladies','Pandora Ladies','Nadege Ladies','Starbucks Ladies',' Bvlgari Ladies','Pandora Nursing','FC Emp Ladies']
general = ['Subway','Tim Hortons','Source','Go Transit', 'Scotia Flow', 'Ent G Microsoft', 'Rest H CO', 'Nadege Family', 'Starbucks Fam2', 'Starbucks Fam1',
'Pandora Family','Nordstrom CO','Ent A3 Sport Chek','Ent J3 Shoppers','Ent A2 Jamies','Cheescake CO','Rest H Ext','Bay West J3']
parking =['FC Esc N','E Parkade P2-N','Ent E','F Parkade P2','E Parkade P3-S','Ent J2','FC Elev S','E Parkade P4-N',
'E Parkade P5-N','E Parkade P1-N','Ent J1','E Parkade P2-S','E Parkade P4-S','E Parkade P5-S','E Parkade P1-S','F Parkade P1',
'FC Elev N','E Parkade P3-N','Ent F Valet','E Parkade P1-E','F Parkade Holt P2','Nord P1 East','Bay North A1','F Parkade Holt P1','C Park Nord L2',
'E Parkade P5-E','E Parkade P4-E','C Park Nord L1','E Parkade P3-E','E Parkade P2-E','Ent H','Ent A1 PB'  ]

# %%
mens_data = df1[ df1['store_name'].isin(mens)]
# week1 = mens_data[(mens_data['date'] > '2017-12-03') & (mens_data['date'] <= '2017-12-09')]

# %%
# visit_mask = df1['traffic_2']
mens_mask = df1['store_name'].isin(mens)

# %%
df1['mens'] = df1['store_name'].isin(mens)
df1['womens'] = df1['store_name'].isin(womens)
df1['general'] = df1['store_name'].isin(general)
df1['parking'] = df1['store_name'].isin(parking)
df1[31950:32000]
# Out:
#                 time_start             time_end  traffic_1  traffic_2  \
# 31950  2017-12-07 10:15:00  2017-12-07 10:30:00         12          1
# 31951  2017-12-07 10:15:00  2017-12-07 10:30:00          4          2
# 31952  2017-12-07 10:15:00  2017-12-07 10:30:00          5          3
# 31953  2017-12-07 10:15:00  2017-12-07 10:30:00          2          5
# 31954  2017-12-07 10:15:00  2017-12-07 10:30:00         49         13
# 31955  2017-12-07 10:15:00  2017-12-07 10:30:00          6          4
# 31956  2017-12-07 10:15:00  2017-12-07 10:30:00         45         58
# 31957  2017-12-07 10:15:00  2017-12-07 10:30:00          9          0
# 31958  2017-12-07 10:15:00  2017-12-07 10:30:00          8          0
# 31959  2017-12-07 10:15:00  2017-12-07 10:30:00          8          0
# 31960  2017-12-07 10:15:00  2017-12-07 10:30:00          4          1
# 31961  2017-12-07 10:15:00  2017-12-07 10:30:00          4          0
# 31962  2017-12-07 10:15:00  2017-12-07 10:30:00          2          3
# 31963  2017-12-07 10:15:00  2017-12-07 10:30:00          0          2
# 31964  2017-12-07 10:15:00  2017-12-07 10:30:00          6          1
# 31965  2017-12-07 10:15:00  2017-12-07 10:30:00         14         18
# 31966  2017-12-07 10:30:00  2017-12-07 10:45:00          1          1
# 
# 31996    Ent G Microsoft    7     12  2017 2017-12-07 10:30:00    49  False
# 31997        Ent F Valet    7     12  2017 2017-12-07 10:30:00    49  False
# 31998       F Parkade P1    7     12  2017 2017-12-07 10:30:00    49  False
# 31999     Babaton Ladies    7     12  2017 2017-12-07 10:30:00    49  False
#
#        womens  general  parking
# 31950    True    False    False
# 31951   False    False     True
# 31952   False    False     True
# 31953   False     True    False
# 31954   False    False     True
# 31955   False    False     True
# 31956   False     True    False
# 31957   False    False     True
# 31958   False    False     True
# 31959   False    False     True
# 31960   False    False     True
# 31961   False    False     True
# 31962   False     True    False
# 31963   False    False     True
# 31964   False    False     True
# 31965   False     True    False
# 31966   False    False    False
# 31967    True    False    False
# 31968   False     True    False
# 31969   False     True    False
# 31970   False    False     True
# 31971   False    False     True
# 31972   False    False     True
# 31973   False    False     True
# 31974   False    False    False
# 31975    True    False    False
# 31976    True    False    False
# 31977   False    False    False
# 31978   False     True    False
# 31979   False     True    False
# 31980   False     True    False
# 31981   False    False     True
# 31982   False     True    False
# 31983   False     True    False
# 31984   False     True    False
# 31985   False     True    False
# 31986    True    False    False
# 31987   False     True    False
# 31988   False     True    False
# 31989   False     True    False
# 31990   False    False     True
# 31991   False     True    False
# 31992   False    False    False
# 31993   False    False    False
# 31994   False     True    False
# 31995   False    False     True
# 31996   False     True    False
# 31997   False    False     True
# 31998   False    False     True
# 31999    True    False    False

# %%
traffic_men = df1.groupby( [ df1['week'], df1['month'], df1['year'], df1['mens']])['traffic_2'].sum().reset_index()
traffic_women = df1.groupby( [ df1['week'], df1['month'], df1['year'], df1['womens'] ])['traffic_2'].sum().reset_index()
traffic_men = traffic_men[ traffic_men.mens] # to extract only the values where mens==True
traffic_men.head(100)
# Out:
#     week  month  year  mens  traffic_2
# 1      1      1  2018  True      97418
# 3      2      1  2018  True      76808
# 5      3      1  2018  True      75892
# 7      4      1  2018  True      75104
# 9      5      1  2018  True      24018
# 11     5      2  2018  True      48909
# 13     6      2  2018  True      67268
# 15     7      2  2018  True      90741
# 17     8      2  2018  True      75934
# 19     9      2  2018  True      20105
# 21    48     12  2017  True      51807
# 23    49     12  2017  True      96164
# 25    50     12  2017  True     106453
# 27    51     12  2017  True     113732
# 29    52     12  2017  True     148553

# %%
traffic_men.drop(['mens'], axis=1,inplace=True)

# %%
traffic_men.rename(index=str, columns={'traffic_2':'men'})
# Out:
#     week  month  year     men
# 1      1      1  2018   97418
# 3      2      1  2018   76808
# 5      3      1  2018   75892
# 7      4      1  2018   75104
# 9      5      1  2018   24018
# 11     5      2  2018   48909
# 13     6      2  2018   67268
# 15     7      2  2018   90741
# 17     8      2  2018   75934
# 19     9      2  2018   20105
# 21    48     12  2017   51807
# 23    49     12  2017   96164
# 25    50     12  2017  106453
# 27    51     12  2017  113732
# 29    52     12  2017  148553

# %%
traffic_women = traffic_women[ traffic_women.womens] # to extract only the values where womens==True
traffic_women.rename(index=str, columns={'traffic_2':'women'})
traffic_women.head(100)
# Out:
#     week  month  year  womens  traffic_2
# 1      1      1  2018    True     159116
# 3      2      1  2018    True     121458
# 5      3      1  2018    True     124547
# 7      4      1  2018    True     123207
# 9      5      1  2018    True      40429
# 11     5      2  2018    True      79418
# 13     6      2  2018    True     109867
# 15     7      2  2018    True     147460
# 17     8      2  2018    True     122811
# 19     9      2  2018    True      32916
# 21    48     12  2017    True      83264
# 23    49     12  2017    True     160815
# 25    50     12  2017    True     180119
# 27    51     12  2017    True     201730
# 29    52     12  2017    True     235750

# %%
combined = traffic_men
combined.rename(index=str, columns={'traffic_2':'men'})
# Out:
#     week  month  year     men
# 1      1      1  2018   97418
# 3      2      1  2018   76808
# 5      3      1  2018   75892
# 7      4      1  2018   75104
# 9      5      1  2018   24018
# 11     5      2  2018   48909
# 13     6      2  2018   67268
# 15     7      2  2018   90741
# 17     8      2  2018   75934
# 19     9      2  2018   20105
# 21    48     12  2017   51807
# 23    49     12  2017   96164
# 25    50     12  2017  106453
# 27    51     12  2017  113732
# 29    52     12  2017  148553

# %%
combined.columns.tolist()
# Out:
# ['week', 'month', 'year', 'traffic_2']

# %%
combined['women'] =  traffic_women['traffic_2']
combined.head(100)
# Out:
#     week  month  year  traffic_2   women
# 1      1      1  2018      97418  159116
# 3      2      1  2018      76808  121458
# 5      3      1  2018      75892  124547
# 7      4      1  2018      75104  123207
# 9      5      1  2018      24018   40429
# 11     5      2  2018      48909   79418
# 13     6      2  2018      67268  109867
# 15     7      2  2018      90741  147460
# 17     8      2  2018      75934  122811
# 19     9      2  2018      20105   32916
# 21    48     12  2017      51807   83264
# 23    49     12  2017      96164  160815
# 25    50     12  2017     106453  180119
# 27    51     12  2017     113732  201730
# 29    52     12  2017     148553  235750

# %%
combined.rename(index=str, columns={'traffic_2':'men'},inplace=True)

# %%
combined.sort_values(by=['year', 'week'], inplace=True)

# %% [markdown]
# combined2 = traffic_men.append(traffic_women)
# combined2.reset_index(drop=True)
# combined2.head(100)

# %%
combined.plot(x='week', y=['men', 'women'], kind='bar')
plt.xticks(rotation=0)
plt.title('Men/Women Visitors')
plt.savefig('Men_Women visitors', dpi=300, edgecolor='w',bbox_inches="tight")
plt.show()

# %%
total_traffic = df1.groupby( [ df1['week'], df1['month'], df1['year'], df1['parking']])['traffic_2'].sum().reset_index()
total_traffic = total_traffic[ total_traffic.parking]
total_traffic.rename(index=str, columns={'traffic_2':'visitors'},inplace=True)
total_traffic.head()
# Out:
#    week  month  year  parking  visitors
# 1     1      1  2018     True    249321
# 3     2      1  2018     True    196851
# 5     3      1  2018     True    200330
# 7     4      1  2018     True    191603
# 9     5      1  2018     True     61803

# %%
total_traffic.sort_values(by=['year', 'week'], inplace=True)

# %%
total_traffic.plot(x='week', y=['visitors'], kind='bar')
plt.xticks(rotation=0)
plt.title('Visitors')
plt.savefig('Visitors.png', dpi=300, edgecolor='w',bbox_inches="tight")
plt.show()
