# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
xls = pd.read_csv('cust_journey/Customer Journey for Month of December.csv', sep=',', usecols=[*range(0, 71)], nrows=100000 )
# Out:
# --------------------------------------------------------------------
# FileNotFoundError                  Traceback (most recent call last)
# <ipython-input-2-c43254cdb476> in <module>
# ----> 1 xls = pd.read_csv('cust_journey/Customer Journey for Month of December.csv', sep=',', usecols=[*range(0, 71)], nrows=100000 )
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'cust_journey/Customer Journey for Month of December.csv' does not exist: b'cust_journey/Customer Journey for Month of December.csv'

# %%
df = pd.DataFrame(xls)

# %%
df.dropna(how='any', inplace=True)

# %%
df.head()
# Out:
#                             Date        Encrypted Mac          Space Name  \
# 38  Fri Dec 01 20:01:20 EST 2017 -3190646203368694242              Uniqlo
# 47  Fri Dec 01 20:01:40 EST 2017 -3179391220073838541              Uniqlo
# 52  Fri Dec 01 20:01:40 EST 2017 -3361362079696780803           Mendocino
# 66  Fri Dec 01 20:02:20 EST 2017 -5480427668429567245   Bath & Body Works
# 83  Fri Dec 01 20:02:50 EST 2017 -4502787887458951171                Aldo
#
#     Space Type   Space Dwell                Space Name.1  Space Type.1  \
# 38       STORE            10           Fragrance Society         STORE
# 47       STORE             0         Vacheron Constantin         STORE
# 52       STORE             2                   Swarovski         STORE
# 66       STORE             0    Fashion Corridor North 1         OTHER
# 83       STORE             2                      Uniqlo         STORE
#
#      Space Dwell.1              Space Name.2  Space Type.2       ...         \
# 38            13.0             Mac Cosmetics         STORE       ...
# 47             2.0          Aldo Accessories         STORE       ...
# 52             3.0                    Sandro         STORE       ...
# 66             6.0    Centre Corridor West 1         OTHER       ...
# 83             3.0               Fairweather         STORE       ...
#
#      Space Dwell.19               Space Name.20  Space Type.20  \
# 38              0.0             Banana Republic          STORE
# 47             19.0       South West Corridor 2          OTHER
# 52              3.0                   Nordstrom          STORE
# 66              0.0    North Corridor Central 1          OTHER
# 83              9.0               Rudolph and I          STORE
#
#      Space Dwell.20               Space Name.21  Space Type.21  \
# 38              0.0    North Corridor Central 1          OTHER
# 47              3.0              Freedom Mobile          STORE
# 52              1.0    North Corridor Central 2          OTHER
# 66              1.0                       Coach          STORE
# 83              8.0                     Versace          STORE
#
#      Space Dwell.21                      Space Name.22  Space Type.22  \
# 38              0.0    The Cheesecake Factory Entrance          OTHER
# 47              5.0              North Corridor West 2          OTHER
# 52              2.0    East Expansion North Corridor 1          OTHER
# 66              1.0         West Expansion EW Corridor          OTHER
# 83              9.0                    Emerald Court 1          OTHER
#
#      Space Dwell.22
# 38              1.0
# 47              0.0
# 52              0.0
# 66              0.0
# 83              0.0
#
# [5 rows x 71 columns]

# %%
df.describe()
# Out:
#         Encrypted Mac   Space Dwell   Space Dwell.1   Space Dwell.2  \
# count    1.002500e+04  10025.000000    10025.000000    10025.000000
# mean    -6.393771e+17      4.924489        5.764289        6.947431
# std      5.503371e+18     11.278904       13.149002       14.432948
# min     -9.214106e+18      0.000000        0.000000        0.000000
# 25%     -5.551373e+18      0.000000        0.000000        1.000000
# 50%     -8.832899e+17      2.000000        2.000000        2.000000
# 75%      4.637077e+18      5.000000        6.000000        7.000000
# max      8.358315e+18    204.000000      510.000000      282.000000
#
#         Space Dwell.3   Space Dwell.4   Space Dwell.5   Space Dwell.6  \
# count    10025.000000    10025.000000    10025.000000    10025.000000
# mean         7.235212        7.121297        6.912120        6.182344
# std         15.137654       16.397644       15.822752       14.271372
# min          0.000000        0.000000        0.000000        0.000000
# 25%          1.000000        1.000000        0.000000        0.000000
# 50%          2.000000        2.000000        2.000000        2.000000
# 75%          7.000000        6.000000        6.000000        5.000000
# max        231.000000      563.000000      364.000000      275.000000
#
#         Space Dwell.7   Space Dwell.8       ...          Space Dwell.13  \
# count    10025.000000    10025.000000       ...            10025.000000
# mean         6.368878        5.721097       ...                5.067531
# std         16.868943       14.505765       ...               12.614920
# min          0.000000        0.000000       ...                0.000000
# 25%          0.000000        0.000000       ...                0.000000
# 50%          2.000000        2.000000       ...                2.000000
# 75%          5.000000        5.000000       ...                5.000000
# max        542.000000      219.000000       ...              260.000000
#
#         Space Dwell.14   Space Dwell.15   Space Dwell.16   Space Dwell.17  \
# count     10025.000000     10025.000000     10025.000000     10025.000000
# mean          5.077107         5.077606         4.861746         5.020748
# std          15.233686        13.128378        12.216377        14.450143
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.000000
# 50%           2.000000         1.000000         2.000000         2.000000
# 75%           5.000000         4.000000         4.000000         4.000000
# max         799.000000       293.000000       364.000000       771.000000
#
#         Space Dwell.18   Space Dwell.19   Space Dwell.20   Space Dwell.21  \
# count     10025.000000     10025.000000     10025.000000     10025.000000
# mean          4.886983         5.479102         5.426135         5.165387
# std          12.764000        13.561195        13.974408        13.980368
# min           0.000000         0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000         0.000000
# 50%           1.000000         2.000000         2.000000         2.000000
# 75%           4.000000         5.000000         5.000000         4.000000
# max         475.000000       294.000000       263.000000       554.000000
#
#         Space Dwell.22
# count     10025.000000
# mean          5.309825
# std          14.046950
# min           0.000000
# 25%           0.000000
# 50%           2.000000
# 75%           5.000000
# max         608.000000
#
# [8 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Date', ' Encrypted Mac', ' Space Name', ' Space Type', ' Space Dwell',
#        ' Space Name.1', ' Space Type.1', ' Space Dwell.1', ' Space Name.2',
#        ' Space Type.2', ' Space Dwell.2', ' Space Name.3', ' Space Type.3',
#        ' Space Dwell.3', ' Space Name.4', ' Space Type.4', ' Space Dwell.4',
#        ' Space Name.5', ' Space Type.5', ' Space Dwell.5', ' Space Name.6',
#        ' Space Type.6', ' Space Dwell.6', ' Space Name.7', ' Space Type.7',
#        ' Space Dwell.7', ' Space Name.8', ' Space Type.8', ' Space Dwell.8',
#        ' Space Name.9', ' Space Type.9', ' Space Dwell.9', ' Space Name.10',
#        ' Space Type.10', ' Space Dwell.10', ' Space Name.11', ' Space Type.11',
#        ' Space Dwell.11', ' Space Name.12', ' Space Type.12',
#        ' Space Dwell.12', ' Space Name.13', ' Space Type.13',
#        ' Space Dwell.13', ' Space Name.14', ' Space Type.14',
#        ' Space Dwell.14', ' Space Name.15', ' Space Type.15',
#        ' Space Dwell.15', ' Space Name.16', ' Space Type.16',
#        ' Space Dwell.16', ' Space Name.17', ' Space Type.17',
#        ' Space Dwell.17', ' Space Name.18', ' Space Type.18',
#        ' Space Dwell.18', ' Space Name.19', ' Space Type.19',
#        ' Space Dwell.19', ' Space Name.20', ' Space Type.20',
#        ' Space Dwell.20', ' Space Name.21', ' Space Type.21',
#        ' Space Dwell.21', ' Space Name.22', ' Space Type.22',
#        ' Space Dwell.22'],
#       dtype='object')

# %%
# rename columns
mapping = { df.columns[1]:'MAC', df.columns[3]:'Space00',  df.columns[6]:'Space1',  df.columns[9]:'Space2',  df.columns[12]:'Space3',  df.columns[15]:'Space4',  df.columns[18]:'Space5',  df.columns[21]:'Space6',  df.columns[24]:'Space7', 
           df.columns[4]:'dwell00', df.columns[7]:'dwell1', df.columns[10]: 'dwell2', df.columns[13]: 'dwell3', df.columns[16]: 'dwell4',df.columns[19]: 'dwell5',df.columns[22]: 'dwell6',df.columns[25]: 'dwell7',df.columns[28]: 'dwell8'          }
df.rename(columns=mapping, inplace=True)

# %%
mapping2 = { df.columns[27]:'Space8', df.columns[30]:'Space9',  df.columns[31]:'dwell9',  df.columns[33]:'Space10',  df.columns[34]:'dwell10',  df.columns[36]:'Space11',  
            df.columns[37]:'dwell11',  df.columns[39]:'Space12',  df.columns[40]:'dwell12', 
           df.columns[42]:'Space13', df.columns[43]:'dwell13', df.columns[45]: 'Space14', df.columns[46]: 'dwell14' }
df.rename(columns=mapping2, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'MAC', ' Space Name', 'Space00', 'dwell00', ' Space Name.1',
#        'Space1', 'dwell1', ' Space Name.2', 'Space2', 'dwell2',
#        ' Space Name.3', 'Space3', 'dwell3', ' Space Name.4', 'Space4',
#        'dwell4', ' Space Name.5', 'Space5', 'dwell5', ' Space Name.6',
#        'Space6', 'dwell6', ' Space Name.7', 'Space7', 'dwell7',
#        ' Space Name.8', 'Space8', 'dwell8', ' Space Name.9', 'Space9',
#        'dwell9', ' Space Name.10', 'Space10', 'dwell10', ' Space Name.11',
#        'Space11', 'dwell11', ' Space Name.12', 'Space12', 'dwell12',
#        ' Space Name.13', 'Space13', 'dwell13', ' Space Name.14', 'Space14',
#        'dwell14', ' Space Name.15', ' Space Type.15', ' Space Dwell.15',
#        ' Space Name.16', ' Space Type.16', ' Space Dwell.16', ' Space Name.17',
#        ' Space Type.17', ' Space Dwell.17', ' Space Name.18', ' Space Type.18',
#        ' Space Dwell.18', ' Space Name.19', ' Space Type.19',
#        ' Space Dwell.19', ' Space Name.20', ' Space Type.20',
#        ' Space Dwell.20', ' Space Name.21', ' Space Type.21',
#        ' Space Dwell.21', ' Space Name.22', ' Space Type.22',
#        ' Space Dwell.22'],
#       dtype='object')

# %%
df.head()
# Out:
#                             Date                  MAC          Space Name  \
# 38  Fri Dec 01 20:01:20 EST 2017 -3190646203368694242              Uniqlo
# 47  Fri Dec 01 20:01:40 EST 2017 -3179391220073838541              Uniqlo
# 52  Fri Dec 01 20:01:40 EST 2017 -3361362079696780803           Mendocino
# 66  Fri Dec 01 20:02:20 EST 2017 -5480427668429567245   Bath & Body Works
# 83  Fri Dec 01 20:02:50 EST 2017 -4502787887458951171                Aldo
#
#    Space00  dwell00                Space Name.1  Space1  dwell1  \
# 38   STORE       10           Fragrance Society   STORE    13.0
# 47   STORE        0         Vacheron Constantin   STORE     2.0
# 52   STORE        2                   Swarovski   STORE     3.0
# 66   STORE        0    Fashion Corridor North 1   OTHER     6.0
# 83   STORE        2                      Uniqlo   STORE     3.0
#
#                 Space Name.2  Space2       ...          Space Dwell.19  \
# 38             Mac Cosmetics   STORE       ...                     0.0
# 47          Aldo Accessories   STORE       ...                    19.0
# 52                    Sandro   STORE       ...                     3.0
# 66    Centre Corridor West 1   OTHER       ...                     0.0
# 83               Fairweather   STORE       ...                     9.0
#
#                  Space Name.20  Space Type.20   Space Dwell.20  \
# 38             Banana Republic          STORE              0.0
# 47       South West Corridor 2          OTHER              3.0
# 52                   Nordstrom          STORE              1.0
# 66    North Corridor Central 1          OTHER              1.0
# 83               Rudolph and I          STORE              8.0
#
#                  Space Name.21  Space Type.21   Space Dwell.21  \
# 38    North Corridor Central 1          OTHER              0.0
# 47              Freedom Mobile          STORE              5.0
# 52    North Corridor Central 2          OTHER              2.0
# 66                       Coach          STORE              1.0
# 83                     Versace          STORE              9.0
#
#                         Space Name.22  Space Type.22   Space Dwell.22
# 38    The Cheesecake Factory Entrance          OTHER              1.0
# 47              North Corridor West 2          OTHER              0.0
# 52    East Expansion North Corridor 1          OTHER              0.0
# 66         West Expansion EW Corridor          OTHER              0.0
# 83                    Emerald Court 1          OTHER              0.0
#
# [5 rows x 71 columns]

# %%
df2 = df # so I don't have to reload df again after messing around

# %%
droplist= [' Space Name', ' Space Name.1', ' Space Name.2',' Space Name.3',  ' Space Name.4', ' Space Name.5', ' Space Name.6', ' Space Name.7', 
        ' Space Name.8', ' Space Name.9', ' Space Name.10', ' Space Name.11', ' Space Name.12',  ' Space Name.13', ' Space Name.14',
        ' Space Name.15', ' Space Type.15', ' Space Dwell.15', ' Space Name.16', ' Space Type.16', ' Space Dwell.16',
        ' Space Name.17', ' Space Type.17', ' Space Dwell.17', ' Space Name.18', ' Space Type.18', ' Space Dwell.18', ' Space Name.19', ' Space Type.19', ' Space Dwell.19',
        ' Space Name.20', ' Space Type.20', ' Space Dwell.20', ' Space Name.21', ' Space Type.21', ' Space Dwell.21', ' Space Name.22', ' Space Type.22', ' Space Dwell.22' ]

# %%
# Note - run the df2 = df EVERY TIME!!!
df2.drop( droplist , inplace=True, axis =1)

# %%
df2
# Out:
#                                Date                  MAC Space00  dwell00  \
# 38     Fri Dec 01 20:01:20 EST 2017 -3190646203368694242   STORE       10
# 47     Fri Dec 01 20:01:40 EST 2017 -3179391220073838541   STORE        0
# 52     Fri Dec 01 20:01:40 EST 2017 -3361362079696780803   STORE        2
# 66     Fri Dec 01 20:02:20 EST 2017 -5480427668429567245   STORE        0
# 83     Fri Dec 01 20:02:50 EST 2017 -4502787887458951171   STORE        2
# 101    Fri Dec 01 20:03:30 EST 2017  4841791676214092387   STORE        1
# 140    Fri Dec 01 20:04:50 EST 2017  8358314298049893884   STORE        0
# 141    Fri Dec 01 20:04:50 EST 2017  1322739155431497324   STORE        2
# 182    Fri Dec 01 20:06:20 EST 2017 -5632635172663340798   OTHER        0
# 191    Fri Dec 01 20:06:30 EST 2017 -9037601284304271449   STORE        3
# 218    Fri Dec 01 20:07:30 EST 2017   277944349989111611   STORE        5
# 219    Fri Dec 01 20:07:30 EST 2017 -4475685973930294045   OTHER        0
# 231    Fri Dec 01 20:07:50 EST 2017 -2146761446034496817   STORE        2
# 241    Fri Dec 01 20:08:10 EST 2017  8084537258552152954   STORE        2
# 245    Fri Dec 01 20:08:20 EST 2017  2511518461570221039   STORE        2
# 313    Fri Dec 01 20:11:10 EST 2017 -5698519493064106625   STORE        1
# 379    Fri Dec 01 20:13:30 EST 2017  5825760290086201860   STORE        1
# 386    Fri Dec 01 20:13:30 EST 2017  1202843135615204066   STORE        6
# 389    Fri Dec 01 20:13:40 EST 2017 -7904329683889186473   STORE        1
# 466    Fri Dec 01 20:16:30 EST 2017  2478784176405658787   STORE        0
# 483    Fri Dec 01 20:17:00 EST 2017 -7842457893236209186   STORE        1
# 508    Fri Dec 01 20:17:40 EST 2017 -5701469653190967740   STORE        0
# 510    Fri Dec 01 20:17:50 EST 2017 -6717329876451087790   OTHER        1
# 535    Fri Dec 01 20:18:40 EST 2017  4834788126350373553   STORE        0
# 551    Fri Dec 01 20:19:10 EST 2017  3629874955241488561   STORE        0
# 569    Fri Dec 01 20:19:50 EST 2017  8336177408681301898   STORE        1
# 724    Fri Dec 01 20:26:40 EST 2017  3572753298527106305   OTHER        0
# 730    Fri Dec 01 20:27:00 EST 2017 -9021613801891117971   OTHER        0
# 753    Fri Dec 01 20:28:20 EST 2017 -5496084252829694605   OTHER        1
# 769    Fri Dec 01 20:29:00 EST 2017 -2246668626630861382   STORE        1
# ...                             ...                  ...     ...      ...
# 99713  Wed Dec 06 14:25:40 EST 2017 -5551373621160677282   STORE        2
# 99718  Wed Dec 06 14:25:50 EST 2017 -2146762366756669130   OTHER        0
# 99722  Wed Dec 06 14:25:50 EST 2017  5997192904290423163   STORE        1
# 99734  Wed Dec 06 14:26:10 EST 2017  4749584167442570847   STORE        2
# 99736  Wed Dec 06 14:26:10 EST 2017  6959624058065761499   STORE        4
# 99759  Wed Dec 06 14:27:30 EST 2017 -5480426861671279875   STORE        3
# 99765  Wed Dec 06 14:27:40 EST 2017 -5480426912574438434   OTHER        2
# 99789  Wed Dec 06 14:28:40 EST 2017 -4356084657416983370   OTHER        0
# 99808  Wed Dec 06 14:29:20 EST 2017  8358313807142997218   STORE        3
# 99812  Wed Dec 06 14:29:50 EST 2017  2363943954055877360   STORE        1
# 99849  Wed Dec 06 14:31:40 EST 2017  2501357798357580132   STORE       12
# 99862  Wed Dec 06 14:32:00 EST 2017 -5698519305720059789   STORE        3
# 99865  Wed Dec 06 14:32:10 EST 2017  3559621161047897345   STORE       10
# 99876  Wed Dec 06 14:32:40 EST 2017 -5701469794191010297   STORE        3
# 99878  Wed Dec 06 14:32:40 EST 2017 -6717951001161325271   STORE        2
# 99888  Wed Dec 06 14:33:10 EST 2017  1332144690076566674   STORE        4
# 99917  Wed Dec 06 14:34:00 EST 2017  4786096934863902471   STORE        1
# 99919  Wed Dec 06 14:34:00 EST 2017  6038609730706631571   STORE       14
# 99930  Wed Dec 06 14:34:30 EST 2017  4786097067491662654   STORE        4
# 99931  Wed Dec 06 14:34:30 EST 2017  3648461006256125598   STORE       26
# 99935  Wed Dec 06 14:34:40 EST 2017 -9021613409506405405   STORE        1
# 99944  Wed Dec 06 14:35:20 EST 2017  7026891700892842851   OTHER        1
# 99946  Wed Dec 06 14:35:20 EST 2017 -2284877594753133313   STORE       13
# 99950  Wed Dec 06 14:35:40 EST 2017  8318999280356533435   STORE        3
# 99953  Wed Dec 06 14:35:50 EST 2017  3559620819625074955   STORE        1
# 99964  Wed Dec 06 14:36:20 EST 2017  2465870671259478833   STORE        4
# 99975  Wed Dec 06 14:36:30 EST 2017 -7832064341464002286   STORE        0
# 99984  Wed Dec 06 14:36:40 EST 2017 -1026510102060190065   STORE        4
# 99990  Wed Dec 06 14:37:00 EST 2017 -9130427307508422108   STORE        0
# 99996  Wed Dec 06 14:37:20 EST 2017   131976451894943001   STORE        0
#
#        Space1  dwell1  Space2  dwell2  Space3  dwell3   ...    Space10  \
# 38      STORE    13.0   STORE     2.0   STORE     0.0   ...      OTHER
# 47      STORE     2.0   STORE    14.0   STORE     1.0   ...      OTHER
# 52      STORE     3.0   STORE     4.0   STORE     0.0   ...      OTHER
# 66      OTHER     6.0   OTHER     1.0   OTHER     3.0   ...      OTHER
# 83      STORE     3.0   STORE     5.0   STORE     5.0   ...      OTHER
# 101     STORE     5.0   STORE     0.0   STORE    10.0   ...      OTHER
# 140     STORE     0.0   STORE     1.0   STORE     1.0   ...      OTHER
# 141     STORE     3.0   STORE     2.0   STORE     3.0   ...      OTHER
# 182     STORE    42.0   STORE     0.0   STORE     0.0   ...      OTHER
# 191     OTHER     0.0   STORE     2.0   OTHER     5.0   ...      OTHER
# 218     OTHER     1.0   STORE     1.0   STORE    28.0   ...      OTHER
# 219     STORE     0.0   STORE     0.0   STORE     1.0   ...      OTHER
# 231     STORE     0.0   STORE     1.0   OTHER     3.0   ...      OTHER
# 241     STORE     3.0   STORE     2.0   STORE     0.0   ...      STORE
# 245     STORE     1.0   STORE     4.0   OTHER    21.0   ...      STORE
# 313     STORE     2.0   OTHER     0.0   STORE     0.0   ...      OTHER
# 379     STORE     3.0   STORE     4.0   STORE     0.0   ...      STORE
# 386     STORE     2.0   OTHER     7.0   STORE     1.0   ...      OTHER
# 389     STORE     0.0   STORE     0.0   OTHER     5.0   ...      OTHER
# 466     STORE     2.0   STORE    15.0   STORE     2.0   ...      STORE
# 483     STORE    36.0   STORE     0.0   STORE     0.0   ...      OTHER
# 508     STORE     1.0   STORE     1.0   STORE     4.0   ...      STORE
# 510     STORE     1.0   STORE     2.0   STORE     2.0   ...      STORE
# 535     STORE     2.0   STORE     0.0   OTHER     7.0   ...      STORE
# 551     STORE     0.0   STORE     1.0   OTHER     0.0   ...      OTHER
# 569     OTHER     1.0   STORE     1.0   STORE     2.0   ...      OTHER
# 724     STORE     0.0   STORE     1.0   OTHER     0.0   ...      OTHER
# 730     OTHER     1.0   STORE     2.0   STORE     8.0   ...      OTHER
# 753     STORE     1.0   STORE     0.0   STORE     0.0   ...      OTHER
# 769     STORE     0.0   OTHER     0.0   OTHER     0.0   ...      STORE
# ...       ...     ...     ...     ...     ...     ...   ...        ...
# 99713   STORE     0.0   STORE     0.0   STORE     3.0   ...      OTHER
# 99718   STORE     4.0   OTHER    14.0   OTHER     3.0   ...      OTHER
# 99722   STORE     0.0   STORE     0.0   STORE     3.0   ...      STORE
# 99734   STORE     0.0   STORE    15.0   STORE     0.0   ...      OTHER
# 99736   STORE     2.0   STORE     0.0   STORE     0.0   ...      OTHER
# 99759   OTHER    25.0   STORE    10.0   STORE     2.0   ...      STORE
# 99765   OTHER    59.0   OTHER     1.0   OTHER    11.0   ...      OTHER
# 99789   STORE     3.0   OTHER     0.0   STORE     1.0   ...      STORE
# 99808   STORE     6.0   OTHER    29.0   OTHER     1.0   ...      OTHER
# 99812   STORE     5.0   STORE     2.0   OTHER     3.0   ...      OTHER
# 99849   OTHER    12.0   STORE     1.0   OTHER     0.0   ...      OTHER
# 99862   STORE     4.0   OTHER     0.0   OTHER     0.0   ...      STORE
# 99865   STORE    12.0   STORE    10.0   STORE     8.0   ...      OTHER
# 99876   STORE     1.0   STORE     0.0   OTHER     1.0   ...      STORE
# 99878   STORE     0.0   STORE    19.0   STORE     1.0   ...      OTHER
# 99888   STORE     2.0   STORE     0.0   STORE     3.0   ...      OTHER
# 99917   STORE    11.0   OTHER    12.0   STORE     3.0   ...      OTHER
# 99919   STORE     1.0   OTHER     0.0   OTHER    13.0   ...      OTHER
# 99930   OTHER     1.0   STORE     4.0   STORE     0.0   ...      OTHER
# 99931   STORE     0.0   OTHER     5.0   OTHER     0.0   ...      STORE
# 99935   STORE     6.0   STORE     0.0   OTHER     8.0   ...      OTHER
# 99944   OTHER     3.0   STORE     7.0   OTHER     1.0   ...      OTHER
# 99946   STORE     3.0   STORE     2.0   STORE     7.0   ...      OTHER
# 99950   STORE    20.0   OTHER     1.0   OTHER     1.0   ...      STORE
# 99953   STORE     4.0   STORE     5.0   STORE    10.0   ...      OTHER
# 99964   STORE     0.0   STORE     0.0   STORE     0.0   ...      OTHER
# 99975   STORE     0.0   STORE     5.0   OTHER     2.0   ...      OTHER
# 99984   STORE     3.0   STORE     2.0   STORE     1.0   ...      OTHER
# 99990   OTHER     2.0   STORE    11.0   STORE     1.0   ...      STORE
# 99996   STORE     0.0   STORE     2.0   OTHER     0.0   ...      OTHER
#
#        dwell10 Space11  dwell11 Space12  dwell12 Space13  dwell13 Space14  \
# 38         0.0   OTHER      2.0   OTHER      3.0   OTHER      4.0   OTHER
# 47         2.0   STORE      0.0   OTHER      4.0   OTHER      0.0   STORE
# 52         2.0   OTHER      0.0   STORE     30.0   STORE     12.0   STORE
# 66         4.0   OTHER      2.0   STORE      0.0   OTHER      4.0   STORE
# 83        41.0   STORE      2.0   STORE      2.0   OTHER      1.0   OTHER
# 101       15.0   STORE      7.0   STORE      1.0   OTHER      1.0   OTHER
# 140        2.0   OTHER      1.0   OTHER      2.0   OTHER      0.0   OTHER
# 141        8.0   OTHER      6.0   STORE      1.0   STORE      1.0   OTHER
# 182        0.0   OTHER      1.0   STORE      0.0   STORE      0.0   OTHER
# 191        0.0   OTHER      0.0   STORE      0.0   OTHER      0.0   STORE
# 218        8.0   STORE      7.0   OTHER      0.0   OTHER      1.0   OTHER
# 219        0.0   OTHER      0.0   STORE      0.0   STORE      1.0   OTHER
# 231        1.0   OTHER      0.0   OTHER      0.0   OTHER      0.0   STORE
# 241        0.0   OTHER      0.0   OTHER      2.0   OTHER      0.0   OTHER
# 245        1.0   OTHER      0.0   STORE      1.0   OTHER     70.0   OTHER
# 313        0.0   OTHER      0.0   OTHER      5.0   OTHER      0.0   OTHER
# 379       10.0   OTHER      0.0   OTHER      1.0   STORE      0.0   OTHER
# 386        4.0   STORE      0.0   OTHER      0.0   OTHER      7.0   STORE
# 389        0.0   STORE      1.0   OTHER      0.0   OTHER      0.0   STORE
# 466        8.0   OTHER     11.0   OTHER      4.0   STORE      1.0   OTHER
# 483        5.0   STORE      3.0   OTHER      0.0   OTHER      0.0   OTHER
# 508        1.0   OTHER      0.0   OTHER      1.0   OTHER      1.0   OTHER
# 510        0.0   STORE      2.0   OTHER      1.0   OTHER      0.0   STORE
# 535       20.0   OTHER     13.0   STORE      1.0   OTHER      4.0   OTHER
# 551       10.0   OTHER      0.0   STORE      0.0   OTHER      1.0   OTHER
# 569        2.0   OTHER      0.0   OTHER      6.0   OTHER      3.0   OTHER
# 724        0.0   STORE      0.0   OTHER      0.0   OTHER      1.0   OTHER
# 730        1.0   STORE     10.0   OTHER      2.0   OTHER      1.0   OTHER
# 753        1.0   OTHER      0.0   OTHER      3.0   OTHER      0.0   OTHER
# 769        0.0   STORE      4.0   OTHER    106.0   OTHER     10.0   STORE
# ...        ...     ...      ...     ...      ...     ...      ...     ...
# 99713      0.0   STORE      3.0   OTHER      2.0   OTHER      5.0   OTHER
# 99718      3.0   OTHER      0.0   STORE      0.0   OTHER      1.0   OTHER
# 99722      1.0   OTHER      0.0   OTHER      3.0   OTHER      0.0   OTHER
# 99734      8.0   OTHER      1.0   OTHER      0.0   OTHER      2.0   STORE
# 99736      1.0   STORE      2.0   OTHER      8.0   STORE      0.0   OTHER
# 99759      1.0   OTHER     20.0   OTHER      6.0   STORE      1.0   OTHER
# 99765     15.0   OTHER      0.0   OTHER      1.0   OTHER      6.0   STORE
# 99789      6.0   STORE      2.0   OTHER      1.0   STORE      2.0   OTHER
# 99808      0.0   OTHER      2.0   STORE      4.0   OTHER      3.0   OTHER
# 99812      1.0   STORE      7.0   OTHER      3.0   STORE      4.0   STORE
# 99849      0.0   OTHER      0.0   OTHER     15.0   STORE      1.0   STORE
# 99862      0.0   OTHER      6.0   STORE      0.0   OTHER      0.0   OTHER
# 99865     22.0   OTHER      0.0   OTHER     23.0   OTHER      7.0   OTHER
# 99876      2.0   STORE      2.0   STORE     11.0   STORE      0.0   STORE
# 99878      0.0   OTHER      1.0   OTHER      0.0   OTHER      0.0   OTHER
# 99888      2.0   OTHER      0.0   STORE      0.0   STORE      3.0   STORE
# 99917      1.0   OTHER      2.0   STORE      0.0   OTHER     11.0   STORE
# 99919      0.0   OTHER      2.0   OTHER      0.0   OTHER      0.0   OTHER
# 99930      1.0   STORE      1.0   OTHER     13.0   STORE      2.0   OTHER
# 99931      0.0   STORE      1.0   STORE      3.0   STORE      0.0   OTHER
# 99935      8.0   STORE      1.0   STORE      1.0   OTHER      1.0   STORE
# 99944      0.0   OTHER     72.0   STORE      2.0   OTHER      3.0   STORE
# 99946      4.0   STORE      6.0   STORE      0.0   STORE      0.0   STORE
# 99950      0.0   STORE      2.0   OTHER    114.0   OTHER      1.0   STORE
# 99953      0.0   STORE      1.0   OTHER      5.0   OTHER      0.0   STORE
# 99964      0.0   OTHER      5.0   OTHER      0.0   OTHER      2.0   OTHER
# 99975     32.0   OTHER      4.0   OTHER      0.0   OTHER      0.0   STORE
# 99984      3.0   OTHER     69.0   OTHER      1.0   STORE      1.0   OTHER
# 99990      1.0   STORE      7.0   OTHER     31.0   OTHER      1.0   OTHER
# 99996      3.0   STORE      1.0   OTHER      2.0   STORE      1.0   OTHER
#
#        dwell14
# 38         4.0
# 47         1.0
# 52         1.0
# 66         4.0
# 83         1.0
# 101        5.0
# 140        0.0
# 141        7.0
# 182        0.0
# 191        0.0
# 218        0.0
# 219        0.0
# 231        0.0
# 241        1.0
# 245        1.0
# 313        3.0
# 379        0.0
# 386       16.0
# 389        1.0
# 466        0.0
# 483        2.0
# 508        6.0
# 510        0.0
# 535        0.0
# 551        0.0
# 569      158.0
# 724        0.0
# 730        5.0
# 753        0.0
# 769        2.0
# ...        ...
# 99713      1.0
# 99718      1.0
# 99722      0.0
# 99734      3.0
# 99736      0.0
# 99759      4.0
# 99765      0.0
# 99789     28.0
# 99808      1.0
# 99812      0.0
# 99849      0.0
# 99862     11.0
# 99865      1.0
# 99876      1.0
# 99878      1.0
# 99888      1.0
# 99917      5.0
# 99919      2.0
# 99930      1.0
# 99931      6.0
# 99935      0.0
# 99944      4.0
# 99946     18.0
# 99950      1.0
# 99953      2.0
# 99964      1.0
# 99975     11.0
# 99984      1.0
# 99990      1.0
# 99996      4.0
#
# [10025 rows x 32 columns]

# %% [markdown]
# ### Add filter columns for all the places where the visitor is in STORE

# %%
# in for where first stop is a store
df2['in_store0'] = (df2['Space1'] == ' STORE')
df2['in_store0'] = df2['in_store0']*1

# and second stop is a store, and so on
df2['in_store1'] = (df2['Space2'] == ' STORE')
df2['in_store1'] = df2['in_store1']*1

df2['in_store2'] = (df2['Space3'] == ' STORE')
df2['in_store2'] = df2['in_store2']*1

df2['in_store3'] = (df2['Space4'] == ' STORE')
df2['in_store3'] = df2['in_store3']*1

df2['in_store4'] = (df2['Space5'] == ' STORE')
df2['in_store4'] = df2['in_store4']*1

df2['in_store5'] = (df2['Space6'] == ' STORE')
df2['in_store5'] = df2['in_store5']*1

df2['in_store6'] = (df2['Space7'] == ' STORE')
df2['in_store6'] = df2['in_store6']*1

df2['in_store7'] = (df2['Space8'] == ' STORE')
df2['in_store7'] = df2['in_store7']*1

df2['in_store8'] = (df2['Space9'] == ' STORE')
df2['in_store8'] = df2['in_store8']*1

df2['in_store9'] = (df2['Space10'] == ' STORE')
df2['in_store9'] = df2['in_store9']*1

df2['in_store10'] = (df2['Space11'] == ' STORE')
df2['in_store10'] = df2['in_store10']*1

df2['in_store11'] = (df2['Space12'] == ' STORE')
df2['in_store11'] = df2['in_store11']*1

df2['in_store12'] = (df2['Space13'] == ' STORE')
df2['in_store12'] = df2['in_store12']*1

df2['in_store13'] = (df2['Space14'] == ' STORE')
df2['in_store13'] = df2['in_store13']*1

# %%
df2.head()
# Out:
#                             Date                  MAC Space00  dwell00  \
# 38  Fri Dec 01 20:01:20 EST 2017 -3190646203368694242   STORE       10
# 47  Fri Dec 01 20:01:40 EST 2017 -3179391220073838541   STORE        0
# 52  Fri Dec 01 20:01:40 EST 2017 -3361362079696780803   STORE        2
# 66  Fri Dec 01 20:02:20 EST 2017 -5480427668429567245   STORE        0
# 83  Fri Dec 01 20:02:50 EST 2017 -4502787887458951171   STORE        2
#
#     Space1  dwell1  Space2  dwell2  Space3  dwell3     ...     in_store4  \
# 38   STORE    13.0   STORE     2.0   STORE     0.0     ...             1
# 47   STORE     2.0   STORE    14.0   STORE     1.0     ...             0
# 52   STORE     3.0   STORE     4.0   STORE     0.0     ...             0
# 66   OTHER     6.0   OTHER     1.0   OTHER     3.0     ...             0
# 83   STORE     3.0   STORE     5.0   STORE     5.0     ...             0
#
#     in_store5 in_store6  in_store7 in_store8  in_store9 in_store10  \
# 38          0         0          0         0          0          0
# 47          1         1          0         0          0          1
# 52          0         0          0         0          0          0
# 66          0         0          1         0          0          0
# 83          0         0          1         0          0          1
#
#     in_store11 in_store12  in_store13
# 38           0          0           0
# 47           0          0           1
# 52           1          1           1
# 66           1          0           1
# 83           1          0           0
#
# [5 rows x 46 columns]

# %% [markdown]
# ### Add filter columns for all the places where the visitor is 'IDLE'

# %%
# filter for where first dwell is 'idle'
df2['idle0'] = (df2['Space1'] == ' OTHER')
df2['idle0'] = df2['idle0']*1

df2['idle1'] = (df2['Space2'] == ' OTHER')
df2['idle1'] = df2['idle1']*1

df2['idle2'] = (df2['Space3'] == ' OTHER')
df2['idle2'] = df2['idle2']*1

df2['idle3'] = (df2['Space4'] == ' OTHER')
df2['idle3'] = df2['idle3']*1
# -------------- breaker --- so I don't go cross-eyed
df2['idle4'] = (df2['Space5'] == ' OTHER')
df2['idle4'] = df2['idle4']*1

df2['idle5'] = (df2['Space6'] == ' OTHER')
df2['idle5'] = df2['idle5']*1

df2['idle6'] = (df2['Space7'] == ' OTHER')
df2['idle6'] = df2['idle6']*1

df2['idle7'] = (df2['Space8'] == ' OTHER')
df2['idle7'] = df2['idle7']*1

# %%
df2.head()
# Out:
#                             Date                  MAC Space00  dwell00  \
# 38  Fri Dec 01 20:01:20 EST 2017 -3190646203368694242   STORE       10
# 47  Fri Dec 01 20:01:40 EST 2017 -3179391220073838541   STORE        0
# 52  Fri Dec 01 20:01:40 EST 2017 -3361362079696780803   STORE        2
# 66  Fri Dec 01 20:02:20 EST 2017 -5480427668429567245   STORE        0
# 83  Fri Dec 01 20:02:50 EST 2017 -4502787887458951171   STORE        2
#
#     Space1  dwell1  Space2  dwell2  Space3  dwell3  ...   in_store12  \
# 38   STORE    13.0   STORE     2.0   STORE     0.0  ...            0
# 47   STORE     2.0   STORE    14.0   STORE     1.0  ...            0
# 52   STORE     3.0   STORE     4.0   STORE     0.0  ...            1
# 66   OTHER     6.0   OTHER     1.0   OTHER     3.0  ...            0
# 83   STORE     3.0   STORE     5.0   STORE     5.0  ...            0
#
#     in_store13 idle0  idle1 idle2  idle3 idle4  idle5 idle6  idle7
# 38           0     0      0     0      0     0      1     1      1
# 47           1     0      0     0      0     1      0     0      1
# 52           1     0      0     0      1     1      1     1      1
# 66           1     1      1     1      1     1      1     1      0
# 83           0     0      0     0      0     1      1     1      0
#
# [5 rows x 54 columns]

# %% [markdown]
# ### Binning times

# %%
import dateutil
df2['dateok'] = df2['Date'].apply(dateutil.parser.parse, dayfirst=True)

# %%
df2.head()
# Out:
#                             Date                  MAC Space00  dwell00  \
# 38  Fri Dec 01 20:01:20 EST 2017 -3190646203368694242   STORE       10
# 47  Fri Dec 01 20:01:40 EST 2017 -3179391220073838541   STORE        0
# 52  Fri Dec 01 20:01:40 EST 2017 -3361362079696780803   STORE        2
# 66  Fri Dec 01 20:02:20 EST 2017 -5480427668429567245   STORE        0
# 83  Fri Dec 01 20:02:50 EST 2017 -4502787887458951171   STORE        2
#
#     Space1  dwell1  Space2  dwell2  Space3  dwell3         ...          \
# 38   STORE    13.0   STORE     2.0   STORE     0.0         ...
# 47   STORE     2.0   STORE    14.0   STORE     1.0         ...
# 52   STORE     3.0   STORE     4.0   STORE     0.0         ...
# 66   OTHER     6.0   OTHER     1.0   OTHER     3.0         ...
# 83   STORE     3.0   STORE     5.0   STORE     5.0         ...
#
#    in_store13  idle0 idle1  idle2 idle3  idle4 idle5  idle6 idle7  \
# 38          0      0     0      0     0      0     1      1     1
# 47          1      0     0      0     0      1     0      0     1
# 52          1      0     0      0     1      1     1      1     1
# 66          1      1     1      1     1      1     1      1     0
# 83          0      0     0      0     0      1     1      1     0
#
#                 dateok
# 38 2017-12-01 20:01:20
# 47 2017-12-01 20:01:40
# 52 2017-12-01 20:01:40
# 66 2017-12-01 20:02:20
# 83 2017-12-01 20:02:50
#
# [5 rows x 55 columns]

# %%
df2.dtypes
# Out:
# Date                  object
# MAC                    int64
# Space00               object
# dwell00                int64
# Space1                object
# dwell1               float64
# Space2                object
# dwell2               float64
# Space3                object
# dwell3               float64
# Space4                object
# dwell4               float64
# Space5                object
# dwell5               float64
# Space6                object
# dwell6               float64
# Space7                object
# dwell7               float64
# Space8                object
# dwell8               float64
# Space9                object
# dwell9               float64
# Space10               object
# dwell10              float64
# Space11               object
# dwell11              float64
# Space12               object
# dwell12              float64
# Space13               object
# dwell13              float64
# Space14               object
# dwell14              float64
# in_store0              int32
# in_store1              int32
# in_store2              int32
# in_store3              int32
# in_store4              int32
# in_store5              int32
# in_store6              int32
# in_store7              int32
# in_store8              int32
# in_store9              int32
# in_store10             int32
# in_store11             int32
# in_store12             int32
# in_store13             int32
# idle0                  int32
# idle1                  int32
# idle2                  int32
# idle3                  int32
# idle4                  int32
# idle5                  int32
# idle6                  int32
# idle7                  int32
# dateok        datetime64[ns]
# dtype: object

# %%
import datetime
df2['Date'] = [datetime.datetime.date(d) for d in df2['dateok']]# extracting date from timestamp
df2['Time'] = [datetime.datetime.time(d) for d in df2['dateok']]# extracting time from timestamp

# %%
df2.head()
# Out:
#           Date                  MAC Space00  dwell00  Space1  dwell1  Space2  \
# 38  2017-12-01 -3190646203368694242   STORE       10   STORE    13.0   STORE
# 47  2017-12-01 -3179391220073838541   STORE        0   STORE     2.0   STORE
# 52  2017-12-01 -3361362079696780803   STORE        2   STORE     3.0   STORE
# 66  2017-12-01 -5480427668429567245   STORE        0   OTHER     6.0   OTHER
# 83  2017-12-01 -4502787887458951171   STORE        2   STORE     3.0   STORE
#
#     dwell2  Space3  dwell3    ...    idle0  idle1 idle2  idle3 idle4  idle5  \
# 38     2.0   STORE     0.0    ...        0      0     0      0     0      1
# 47    14.0   STORE     1.0    ...        0      0     0      0     1      0
# 52     4.0   STORE     0.0    ...        0      0     0      1     1      1
# 66     1.0   OTHER     3.0    ...        1      1     1      1     1      1
# 83     5.0   STORE     5.0    ...        0      0     0      0     1      1
#
#    idle6  idle7              dateok      Time
# 38     1      1 2017-12-01 20:01:20  20:01:20
# 47     0      1 2017-12-01 20:01:40  20:01:40
# 52     1      1 2017-12-01 20:01:40  20:01:40
# 66     1      0 2017-12-01 20:02:20  20:02:20
# 83     1      0 2017-12-01 20:02:50  20:02:50
#
# [5 rows x 56 columns]

# %%
df2['hod'] = [t.hour for t in df2.Time]
df2.head()
# Out:
#           Date                  MAC Space00  dwell00  Space1  dwell1  Space2  \
# 38  2017-12-01 -3190646203368694242   STORE       10   STORE    13.0   STORE
# 47  2017-12-01 -3179391220073838541   STORE        0   STORE     2.0   STORE
# 52  2017-12-01 -3361362079696780803   STORE        2   STORE     3.0   STORE
# 66  2017-12-01 -5480427668429567245   STORE        0   OTHER     6.0   OTHER
# 83  2017-12-01 -4502787887458951171   STORE        2   STORE     3.0   STORE
#
#     dwell2  Space3  dwell3 ...  idle1  idle2 idle3  idle4 idle5  idle6 idle7  \
# 38     2.0   STORE     0.0 ...      0      0     0      0     1      1     1
# 47    14.0   STORE     1.0 ...      0      0     0      1     0      0     1
# 52     4.0   STORE     0.0 ...      0      0     1      1     1      1     1
# 66     1.0   OTHER     3.0 ...      1      1     1      1     1      1     0
# 83     5.0   STORE     5.0 ...      0      0     0      1     1      1     0
#
#                 dateok      Time  hod
# 38 2017-12-01 20:01:20  20:01:20   20
# 47 2017-12-01 20:01:40  20:01:40   20
# 52 2017-12-01 20:01:40  20:01:40   20
# 66 2017-12-01 20:02:20  20:02:20   20
# 83 2017-12-01 20:02:50  20:02:50   20
#
# [5 rows x 57 columns]

# %%
df2['interval_of_day'] = pd.cut(df2['hod'], bins=4, labels=['morning', 'mid-day', 'evening', 'night'])

# %%
df2.head()
# Out:
#           Date                  MAC Space00  dwell00  Space1  dwell1  Space2  \
# 38  2017-12-01 -3190646203368694242   STORE       10   STORE    13.0   STORE
# 47  2017-12-01 -3179391220073838541   STORE        0   STORE     2.0   STORE
# 52  2017-12-01 -3361362079696780803   STORE        2   STORE     3.0   STORE
# 66  2017-12-01 -5480427668429567245   STORE        0   OTHER     6.0   OTHER
# 83  2017-12-01 -4502787887458951171   STORE        2   STORE     3.0   STORE
#
#     dwell2  Space3  dwell3       ...        idle2  idle3 idle4  idle5 idle6  \
# 38     2.0   STORE     0.0       ...            0      0     0      1     1
# 47    14.0   STORE     1.0       ...            0      0     1      0     0
# 52     4.0   STORE     0.0       ...            0      1     1      1     1
# 66     1.0   OTHER     3.0       ...            1      1     1      1     1
# 83     5.0   STORE     5.0       ...            0      0     1      1     1
#
#     idle7              dateok      Time hod  interval_of_day
# 38      1 2017-12-01 20:01:20  20:01:20  20            night
# 47      1 2017-12-01 20:01:40  20:01:40  20            night
# 52      1 2017-12-01 20:01:40  20:01:40  20            night
# 66      0 2017-12-01 20:02:20  20:02:20  20            night
# 83      0 2017-12-01 20:02:50  20:02:50  20            night
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Save my dataframe as pkl file so no need to read csv and run all cells again

# %% [markdown]
# import pickle
# # only needs to be run once
# with open('cust_journey.pickle', 'wb', -1) as handle:
#     pickle.dump(df2, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df_customer_journey = pd.read_pickle('./cust_journey.pickle')
print(df_customer_journey.head())
# Out:
#           Date                  MAC Space00  dwell00  Space1  dwell1  Space2  \
# 38  2017-12-01 -3190646203368694242   STORE       10   STORE    13.0   STORE
# 47  2017-12-01 -3179391220073838541   STORE        0   STORE     2.0   STORE
# 52  2017-12-01 -3361362079696780803   STORE        2   STORE     3.0   STORE
# 66  2017-12-01 -5480427668429567245   STORE        0   OTHER     6.0   OTHER
# 83  2017-12-01 -4502787887458951171   STORE        2   STORE     3.0   STORE
#
#     dwell2  Space3  dwell3       ...        idle2  idle3 idle4  idle5 idle6  \
# 38     2.0   STORE     0.0       ...            0      0     0      1     1
# 47    14.0   STORE     1.0       ...            0      0     1      0     0
# 52     4.0   STORE     0.0       ...            0      1     1      1     1
# 66     1.0   OTHER     3.0       ...            1      1     1      1     1
# 83     5.0   STORE     5.0       ...            0      0     1      1     1
#
#     idle7              dateok      Time hod  interval_of_day
# 38      1 2017-12-01 20:01:20  20:01:20  20            night
# 47      1 2017-12-01 20:01:40  20:01:40  20            night
# 52      1 2017-12-01 20:01:40  20:01:40  20            night
# 66      0 2017-12-01 20:02:20  20:02:20  20            night
# 83      0 2017-12-01 20:02:50  20:02:50  20            night
#
# [5 rows x 58 columns]

# %%
df_heat = df_customer_journey

# %%
df_heat.columns
# Out:
# Index(['Date', 'MAC', 'Space00', 'dwell00', 'Space1', 'dwell1', 'Space2',
#        'dwell2', 'Space3', 'dwell3', 'Space4', 'dwell4', 'Space5', 'dwell5',
#        'Space6', 'dwell6', 'Space7', 'dwell7', 'Space8', 'dwell8', 'Space9',
#        'dwell9', 'Space10', 'dwell10', 'Space11', 'dwell11', 'Space12',
#        'dwell12', 'Space13', 'dwell13', 'Space14', 'dwell14', 'in_store0',
#        'in_store1', 'in_store2', 'in_store3', 'in_store4', 'in_store5',
#        'in_store6', 'in_store7', 'in_store8', 'in_store9', 'in_store10',
#        'in_store11', 'in_store12', 'in_store13', 'idle0', 'idle1', 'idle2',
#        'idle3', 'idle4', 'idle5', 'idle6', 'idle7', 'dateok', 'Time', 'hod',
#        'interval_of_day'],
#       dtype='object')

# %%
df_heat=df2.groupby(['interval_of_day'])['in_store0',
        'in_store1', 'in_store2', 'in_store3', 'in_store4',
        'in_store5', 'in_store6',
        'in_store7', 'in_store8', 'in_store9', 'in_store10',
        'in_store11', 'in_store12', 'in_store13',
        'idle0', 'idle1', 'idle2', 'idle3', 'idle4', 'idle5',
        'idle6', 'idle7'           
                                        ].sum().reset_index()

# %%
df_heat
# Out:
#   interval_of_day  in_store0  in_store1  in_store2  in_store3  in_store4  \
# 0         morning       1369       1264       1112        896        773
# 1         mid-day       3826       3514       3166       2616       2139
# 2         evening       2931       2641       2298       1920       1603
# 3           night        442        414        335        279        230
#
#    in_store5  in_store6  in_store7  in_store8  ...    in_store12  in_store13  \
# 0        627        535        543        530  ...           525         539
# 1       1750       1569       1493       1395  ...          1485        1520
# 2       1342       1168       1057       1051  ...          1136        1148
# 3        191        170        160        146  ...           152         149
#
#    idle0  idle1  idle2  idle3  idle4  idle5  idle6  idle7
# 0    199    304    456    672    795    941   1033   1025
# 1    649    961   1309   1859   2336   2725   2906   2982
# 2    514    804   1147   1525   1842   2103   2277   2388
# 3     95    123    202    258    307    346    367    377
#
# [4 rows x 23 columns]

# %%
df_heat.dtypes
# Out:
# interval_of_day    category
# in_store0             int32
# in_store1             int32
# in_store2             int32
# in_store3             int32
# in_store4             int32
# in_store5             int32
# in_store6             int32
# in_store7             int32
# in_store8             int32
# in_store9             int32
# in_store10            int32
# in_store11            int32
# in_store12            int32
# in_store13            int32
# idle0                 int32
# idle1                 int32
# idle2                 int32
# idle3                 int32
# idle4                 int32
# idle5                 int32
# idle6                 int32
# idle7                 int32
# dtype: object

# %%
codes = {'morning':1, 'mid-day':2, 'evening':3, 'night':4}
df_heat['interval_of_day'] = df_heat['interval_of_day'].map(codes)

# %%
df_heat.dtypes
# Out:
# interval_of_day    int64
# in_store0          int32
# in_store1          int32
# in_store2          int32
# in_store3          int32
# in_store4          int32
# in_store5          int32
# in_store6          int32
# in_store7          int32
# in_store8          int32
# in_store9          int32
# in_store10         int32
# in_store11         int32
# in_store12         int32
# in_store13         int32
# idle0              int32
# idle1              int32
# idle2              int32
# idle3              int32
# idle4              int32
# idle5              int32
# idle6              int32
# idle7              int32
# dtype: object

# %%
df_heat
# Out:
#    interval_of_day  in_store0  in_store1  in_store2  in_store3  in_store4  \
# 0                1       1369       1264       1112        896        773
# 1                2       3826       3514       3166       2616       2139
# 2                3       2931       2641       2298       1920       1603
# 3                4        442        414        335        279        230
#
#    in_store5  in_store6  in_store7  in_store8  ...    in_store12  in_store13  \
# 0        627        535        543        530  ...           525         539
# 1       1750       1569       1493       1395  ...          1485        1520
# 2       1342       1168       1057       1051  ...          1136        1148
# 3        191        170        160        146  ...           152         149
#
#    idle0  idle1  idle2  idle3  idle4  idle5  idle6  idle7
# 0    199    304    456    672    795    941   1033   1025
# 1    649    961   1309   1859   2336   2725   2906   2982
# 2    514    804   1147   1525   1842   2103   2277   2388
# 3     95    123    202    258    307    346    367    377
#
# [4 rows x 23 columns]

# %%
df_heat.columns
# Out:
# Index(['interval_of_day', 'in_store0', 'in_store1', 'in_store2', 'in_store3',
#        'in_store4', 'in_store5', 'in_store6', 'in_store7', 'in_store8',
#        'in_store9', 'in_store10', 'in_store11', 'in_store12', 'in_store13',
#        'idle0', 'idle1', 'idle2', 'idle3', 'idle4', 'idle5', 'idle6', 'idle7'],
#       dtype='object')

# %% [markdown]
# # Save the df again for ease of plotting, now that the data is ready

# %% [markdown]
# with open('df_heat.pickle', 'wb', -1) as handle:
#     pickle.dump(df2, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df_customer_journey = pd.read_pickle('./df_heat.pickle')
print(df_heat.head())
# Out:
#    interval_of_day  in_store0  in_store1  in_store2  in_store3  in_store4  \
# 0                1       1369       1264       1112        896        773
# 1                2       3826       3514       3166       2616       2139
# 2                3       2931       2641       2298       1920       1603
# 3                4        442        414        335        279        230
#
#    in_store5  in_store6  in_store7  in_store8  ...    in_store12  in_store13  \
# 0        627        535        543        530  ...           525         539
# 1       1750       1569       1493       1395  ...          1485        1520
# 2       1342       1168       1057       1051  ...          1136        1148
# 3        191        170        160        146  ...           152         149
#
#    idle0  idle1  idle2  idle3  idle4  idle5  idle6  idle7
# 0    199    304    456    672    795    941   1033   1025
# 1    649    961   1309   1859   2336   2725   2906   2982
# 2    514    804   1147   1525   1842   2103   2277   2388
# 3     95    123    202    258    307    346    367    377
#
# [4 rows x 23 columns]

# %%
df_instore = df_heat[['interval_of_day', 'in_store0', 'in_store1', 'in_store2', 'in_store3',
       'in_store4', 'in_store5', 'in_store6', 'in_store7', 'in_store8',
       'in_store9', 'in_store10', 'in_store11', 'in_store12', 'in_store13']]

# %%
df_idle = df_heat[['interval_of_day',
       'idle0', 'idle1', 'idle2', 'idle3', 'idle4', 'idle5', 'idle6', 'idle7']]

# %% [markdown]
# # Plotting

# %%
# for some reason the data has to be reimported every time!!
import seaborn as sns
df_instore = df_instore.melt('interval_of_day', var_name='cols',  value_name='vals')
current_palette = sns.color_palette("hls", 8)
sns.factorplot(x="interval_of_day", y="vals", hue='cols', data=df_instore)
plt.savefig('Dwell_time in_store.png', dpi=300)
plt.show()

# %%
# for some reason the data has to be reimported every time!!
import seaborn as sns
df_idle = df_idle.melt('interval_of_day', var_name='cols',  value_name='vals')
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
current_palette = sns.color_palette(flatui)
# oe
# current_palette = sns.color_palette("husl", 8)
g = sns.factorplot(x="interval_of_day", y="vals", hue='cols', data=df_idle, linestyles='dashed')
plt.ylim(0, 4000) # to make both graphs useful for side by side comparison
plt.savefig('Dwell_time not_in_store.png', dpi=300)
plt.show()
