# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
poverty = pd.read_csv('./MPI_national.csv', sep=',')
df = pd.DataFrame(poverty)
# df.head()
# df.describe()
# df.plot()
# df.hist( figsize = (10,10))
# df.boxplot(column = 'MPI Rural', figsize = (10,10))
# df.boxplot( figsize = (10,10))
df['total_MPI'] = df['MPI Urban'] + df['MPI Rural']
is_poor = df['total_MPI'] >= 0.20
df[is_poor]
# df[is_poor].describe()
# df[is_poor].count()
# Out:
#      ISO                            Country  MPI Urban  Headcount Ratio Urban  \
# 41   BOL    Bolivia, Plurinational State of      0.019                    4.9
# 49   LAO   Lao People's Democratic Republic      0.032                    7.4
# 50   ZWE                           Zimbabwe      0.034                    8.7
# 54   MMR                            Myanmar      0.040                    9.6
# 55   LSO                            Lesotho      0.044                   11.0
# 56   GAB                              Gabon      0.044                   10.9
# 57   GTM                          Guatemala      0.048                   10.7
# 58   IND                              India      0.064                   14.8
# 60   GHA                              Ghana      0.075                   17.6
# 61   KEN                              Kenya      0.076                   17.3
# 62   YEM                              Yemen      0.080                   19.0
# 63   TGO                               Togo      0.081                   19.6
# 64   COM                            Comoros      0.084                   18.5
# 65   PAK                           Pakistan      0.087                   20.0
# 66   NAM                            Namibia      0.087                   20.3
# 67   CMR                           Cameroon      0.091                   19.9
# 68   MWI                             Malawi      0.098                   23.2
# 69   BGD                         Bangladesh      0.100                   22.5
# 70   COG                 Congo, Republic of      0.105                   24.5
# 71   RWA                             Rwanda      0.110                   24.8
# 72   HTI                              Haiti      0.112                   25.2
# 73   MDG                         Madagascar      0.113                   24.9
# 74   MRT                         Mauritania      0.119                   25.2
# 75   TZA       Tanzania, United Republic of      0.122                   27.7
# 76   DJI                           Djibouti      0.127                   27.2
# 77   ZMB                             Zambia      0.130                   29.5
# 78   NGA                            Nigeria      0.132                   28.1
# 79   AFG                        Afghanistan      0.132                   28.8
# 80   UGA                             Uganda      0.133                   29.2
# 81   SDN                              Sudan      0.133                   28.7
# 82   SEN                            Senegal      0.142                   29.7
# 83   CIV                      Cote d'Ivoire      0.164                   35.0
# 84   GIN                             Guinea      0.176                   37.7
# 85   TLS                        Timor-Leste      0.176                   37.3
# 86   GMB                             Gambia      0.183                   38.3
# 87   MLI                               Mali      0.189                   40.9
# 88   MOZ                         Mozambique      0.189                   38.2
# 89   BEN                              Benin      0.192                   41.0
# 90   GNB                      Guinea-Bissau      0.199                   43.6
# 91   BDI                            Burundi      0.209                   43.1
# 92   BFA                       Burkina Faso      0.226                   45.8
# 93   COD  Congo, Democratic Republic of the      0.228                   48.6
# 94   ETH                           Ethiopia      0.230                   46.4
# 95   SLE                       Sierra Leone      0.271                   56.3
# 96   NER                              Niger      0.276                   53.9
# 97   CAF           Central African Republic      0.289                   58.2
# 98   LBR                            Liberia      0.290                   60.5
# 99   SOM                            Somalia      0.293                   55.9
# 100  TCD                               Chad      0.351                   64.8
# 101  SSD                        South Sudan      0.459                   82.5
#
#      Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 41                             39.4      0.191                  42.98
# 49                             43.4      0.223                  43.32
# 50                             39.3      0.202                  46.27
# 54                             41.7      0.168                  37.46
# 55                             39.8      0.179                  40.43
# 56                             40.7      0.209                  46.55
# 57                             44.5      0.161                  35.05
# 58                             43.3      0.250                  53.49
# 60                             42.7      0.235                  49.42
# 61                             43.6      0.245                  51.44
# 62                             42.1      0.304                  57.72
# 63                             41.5      0.356                  68.55
# 64                             45.2      0.213                  43.99
# 65                             43.3      0.299                  55.70
# 66                             43.0      0.288                  61.46
# 67                             45.6      0.393                  70.18
# 68                             42.4      0.277                  58.90
# 69                             44.7      0.231                  48.21
# 70                             42.8      0.316                  66.45
# 71                             44.2      0.289                  59.78
# 72                             44.6      0.341                  65.90
# 73                             45.3      0.396                  73.70
# 74                             47.0      0.413                  72.92
# 75                             44.3      0.351                  68.56
# 76                             46.6      0.440                  83.18
# 77                             44.0      0.380                  74.20
# 78                             47.0      0.416                  69.98
# 79                             45.8      0.347                  64.66
# 80                             45.5      0.408                  77.07
# 81                             46.3      0.356                  64.50
# 82                             47.7      0.472                  81.04
# 83                             46.8      0.429                  78.04
# 84                             46.6      0.591                  92.61
# 85                             47.3      0.414                  77.03
# 86                             47.8      0.459                  81.97
# 87                             46.3      0.530                  87.73
# 88                             49.6      0.480                  83.90
# 89                             46.8      0.386                  76.90
# 90                             45.7      0.507                  85.36
# 91                             48.5      0.481                  84.91
# 92                             49.4      0.621                  94.66
# 93                             47.0      0.486                  88.18
# 94                             49.5      0.637                  96.27
# 95                             48.2      0.551                  92.03
# 96                             51.2      0.669                  96.19
# 97                             49.7      0.519                  89.79
# 98                             48.0      0.481                  84.86
# 99                             52.4      0.651                  96.92
# 100                            54.1      0.609                  93.41
# 101                            55.7      0.591                  94.00
#
#      Intensity of Deprivation Rural  total_MPI
# 41                             44.4      0.210
# 49                             51.4      0.255
# 50                             43.7      0.236
# 54                             44.8      0.208
# 55                             44.3      0.223
# 56                             44.8      0.253
# 57                             45.9      0.209
# 58                             46.7      0.314
# 60                             47.5      0.310
# 61                             47.5      0.321
# 62                             52.7      0.384
# 63                             51.9      0.437
# 64                             48.5      0.297
# 65                             53.6      0.386
# 66                             46.9      0.375
# 67                             56.0      0.484
# 68                             47.0      0.375
# 69                             47.9      0.331
# 70                             47.5      0.421
# 71                             48.4      0.399
# 72                             51.7      0.453
# 73                             53.8      0.509
# 74                             56.6      0.532
# 75                             51.2      0.473
# 76                             52.9      0.567
# 77                             51.3      0.510
# 78                             59.5      0.548
# 79                             53.6      0.479
# 80                             52.9      0.541
# 81                             55.1      0.489
# 82                             58.3      0.614
# 83                             55.0      0.593
# 84                             63.9      0.767
# 85                             53.7      0.590
# 86                             56.0      0.642
# 87                             60.5      0.719
# 88                             57.2      0.669
# 89                             50.2      0.578
# 90                             59.4      0.706
# 91                             56.6      0.690
# 92                             65.6      0.847
# 93                             55.1      0.714
# 94                             66.2      0.867
# 95                             59.8      0.822
# 96                             69.5      0.945
# 97                             57.8      0.808
# 98                             56.6      0.771
# 99                             67.2      0.944
# 100                            65.2      0.960
# 101                            62.8      1.050

# %%
poverty_sub = pd.read_csv('./MPI_subnational.csv', sep=',')
# poverty_sub.hist( figsize = (10,10))
df_regional = pd.DataFrame(poverty_sub)
# print(df_regional)
# regional_count = df_regional[['Country','World region']].groupby('World region').count()
# regional_count = df_regional[['World region', 'Country']].groupby('Country').count()
regional_count = df_regional[[ 'Country', 'Intensity of deprivation Regional']].groupby('Intensity of deprivation Regional').count()
regional_count
final_df = df.merge(df_regional, on='Country', how='inner')
final_df.head()
is_really_poor = final_df['total_MPI'] >=0.20
del final_df['ISO country code']
del final_df['Headcount Ratio Regional']
del final_df['Headcount Ratio Rural']
del final_df['Headcount Ratio Urban']
final_df[is_really_poor]
# test_ISO = pd.Series(final_df['ISO'])
# test_country = pd.Series(final_df['Country'])
# test_ser
# test_country
# Out:
#      ISO                          Country  MPI Urban  \
# 243  BOL  Bolivia, Plurinational State of      0.019
# 244  BOL  Bolivia, Plurinational State of      0.019
# 245  BOL  Bolivia, Plurinational State of      0.019
# 246  BOL  Bolivia, Plurinational State of      0.019
# 247  BOL  Bolivia, Plurinational State of      0.019
# ..   ...                              ...        ...
# 979  SSD                      South Sudan      0.459
# 980  SSD                      South Sudan      0.459
# 981  SSD                      South Sudan      0.459
# 982  SSD                      South Sudan      0.459
# 983  SSD                      South Sudan      0.459
#
#      Intensity of Deprivation Urban  MPI Rural  \
# 243                            39.4      0.191
# 244                            39.4      0.191
# 245                            39.4      0.191
# 246                            39.4      0.191
# 247                            39.4      0.191
# ..                              ...        ...
# 979                            55.7      0.591
# 980                            55.7      0.591
# 981                            55.7      0.591
# 982                            55.7      0.591
# 983                            55.7      0.591
#
#      Intensity of Deprivation Rural  total_MPI     Sub-national region  \
# 243                            44.4       0.21              Chuquisaca
# 244                            44.4       0.21                  La Paz
# 245                            44.4       0.21              Cochabamba
# 246                            44.4       0.21                   Oruro
# 247                            44.4       0.21                  Potosð
# ..                              ...        ...                     ...
# 979                            62.8       1.05  Western Bahr el Ghazal
# 980                            62.8       1.05                   Lakes
# 981                            62.8       1.05       Western Equatoria
# 982                            62.8       1.05       Central Equatoria
# 983                            62.8       1.05       Eastern Equatoria
#
#                     World region  MPI National  MPI Regional  \
# 243  Latin America and Caribbean         0.089         0.145
# 244  Latin America and Caribbean         0.089         0.077
# 245  Latin America and Caribbean         0.089         0.105
# 246  Latin America and Caribbean         0.089         0.073
# 247  Latin America and Caribbean         0.089         0.168
# ..                           ...           ...           ...
# 979           Sub-Saharan Africa         0.557         0.491
# 980           Sub-Saharan Africa         0.557         0.605
# 981           Sub-Saharan Africa         0.557         0.456
# 982           Sub-Saharan Africa         0.557         0.391
# 983           Sub-Saharan Africa         0.557         0.561
#
#      Intensity of deprivation Regional
# 243                               45.4
# 244                               41.8
# 245                               45.0
# 246                               42.3
# 247                               46.3
# ..                                 ...
# 979                               57.9
# 980                               62.5
# 981                               53.5
# 982                               51.7
# 983                               60.7
#
# [598 rows x 12 columns]

# %%
countries = final_df['Country'].unique().tolist()
len(countries)
codes = final_df['ISO'].unique().tolist()
len(codes)
graph_country = 'South Sudan'
mask = final_df['Country'].str.contains(graph_country)
stage = final_df[mask]
# print(stage)
# plt.xlabel(final_df['Sub-national region'])
# stage.plot(y=11)
regions = stage['Sub-national region'].values
indexof = stage['MPI Regional'].values

plt.plot(regions, indexof)
plt.title(graph_country)
plt.ylabel('MPI')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
# it will be interesting to show how the MPI changes in relation to the
# urban centers
